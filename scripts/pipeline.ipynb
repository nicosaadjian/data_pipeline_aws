# %%
import pandas as pd

subte_csv = r'C:\Users\nicos\OneDrive\Escritorio\data_pipeline\data\bocas-de-subte.csv'

df = pd.read_csv(subte_csv)

# display(df)

# print(df.columns)

rename_dict = {
    'long': 'Longitud', 
    'lat' : 'Latitud', 
    'id'  : 'Id', 
    'linea': 'Linea', 
    'estacion': 'Estacion', 
    'numero_de_': 'Numero_De', 
    'destino_bo' : 'Destino_Bo',
    'lineas_de_' : 'Lineas_De', 
    'cierra_fin' : 'Cierra_Fin', 
    'escalera_p' : 'Escalera_P', 
    'escalera_m' : 'Escalera_M', 
    'ascensor' : 'Ascensor',
    'rampa' : 'Rampa', 
    'salvaescal' : 'SalvaEscalera', 
    'calle' : 'Calle', 
    'altura' : 'Altura', 
    'calle2' : 'Calle2', 
    'barrio' : 'Barrio', 
    'comuna' : 'Columna',
    'observacio' : 'Observacion', 
    'Objeto' : 'Objeto', 
    'dom_norma' : 'Dom_Norma', 
    'dom_orig' : 'Dom_Origin'
}

df.rename(columns=rename_dict, inplace=True)

cols_to_keep = ['Id', 'Estacion', 'Barrio', 'Calle', 'Calle2', 'Ascensor']
display(df[cols_to_keep])

# aca vamos a hacer el sink a snowflake sobre este dataframe.
# la idea es hacer un dashboard donde haya un grafico de torta que muestre la proporcion entre barrios y cantidad de bocas de subte que tienen
# Out:
#       Id                               Estacion       Barrio  \
# 0      1              TRIBUNALES - TEATRO COLÓN  San Nicolas
# 1      2              TRIBUNALES - TEATRO COLÓN  San Nicolas
# 2      3                              LAS HERAS          NaN
# 3      4                                CÓRDOBA          NaN
# 4      5                             CORRIENTES          NaN
# ..   ...                                    ...          ...
# 374  378                         CORREO CENTRAL  San Nicolas
# 375  379                         CORREO CENTRAL  San Nicolas
# 376  380                         CORREO CENTRAL  San Nicolas
# 377  381                         CORREO CENTRAL  San Nicolas
# 378  382  FACULTAD DE DERECHO - JULIETA LANTERI     Recoleta
#
#                            Calle                  Calle2  Ascensor
# 0                       Libertad                     NaN     False
# 1                        Lavalle                     NaN     False
# 2                     Pueyrredon                     NaN     False
# 3                     Pueyrredon                     NaN      True
# 4                     Pueyrredón                     NaN      True
# ..                           ...                     ...       ...
# 374                    Sarmiento                     NaN     False
# 375                Av Corrientes                     NaN     False
# 376                 Leandro Alem                     NaN     False
# 377                 Leandro Alem                     NaN     False
# 378  Figueroa Alcorta, Pres. Av.  Gonzalez, Julio Victor      True
#
# [379 rows x 6 columns]
